# %% [markdown]
# Pandas series
#
# Series is a 1D array capable of holding any type of data type

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
list=[10,20,30]
arr=([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
